# %%
from bs4 import BeautifulSoup as bs
import requests 
import pandas as pd
from urllib.request import urlopen as uReq
import logging

# %% [markdown]
# ## Request page source from url

# %%
flipkart_url ="https://www.flipkart.com/search?q=" + "watches"

# %%
flipkart_url
# Out:
# 'https://www.flipkart.com/search?q=watches'

# %%
urlclient = uReq(flipkart_url)

# %%
urlclient

# %%
flipkart_page=urlclient.read()

# %%
flipkart_page
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.c48a12.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.0d82ef.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.png"/><link rel="apple-touch-icon" 
# ...

# %%
flipcard_html=bs(flipkart_page,'html.parser')

# %%
flipcard_html
# Out:
# <!DOCTYPE html>
# ...

# %%
bigbox = flipcard_html.findAll('div',{"class":"_1sdMkc LFEi7Z"})

# %%
len(bigbox)
# Out:
# 40

# %%
"https://www.flipkart.com" +bigbox[8].a['href']
# Out:
# 'https://www.flipkart.com/fossil-izzy-analog-watch-women/p/itm522147d011818?pid=WATFWYU3ZGMR58SY&lid=LSTWATFWYU3ZGMR58SYKWQE2Z&marketplace=FLIPKART&q=watches&store=r18&srno=s_1_9&otracker=search&fm=organic&iid=8edac1cf-dc5c-4bc0-b321-1e2e18092650.WATFWYU3ZGMR58SY.SEARCH&ppt=None&ppn=None&ssid=fd949nxt4w0000001716871325720&qH=2d6b6aad43dffa91'

# %%
productlink = "https://www.flipkart.com" +bigbox[8].a['href']

# %%
productlink
# Out:
# 'https://www.flipkart.com/fossil-izzy-analog-watch-women/p/itm522147d011818?pid=WATFWYU3ZGMR58SY&lid=LSTWATFWYU3ZGMR58SYKWQE2Z&marketplace=FLIPKART&q=watches&store=r18&srno=s_1_9&otracker=search&fm=organic&iid=8edac1cf-dc5c-4bc0-b321-1e2e18092650.WATFWYU3ZGMR58SY.SEARCH&ppt=None&ppn=None&ssid=fd949nxt4w0000001716871325720&qH=2d6b6aad43dffa91'

# %%
for i in bigbox:
    print("https://www.flipkart.com" +i.a['href'])
# Out:
# https://www.flipkart.com/hala-6-months-warranty-sport-watch-ultra-led-square-water-resist-feature-digital-men/p/itm2fda5c988a521?pid=WATG3VYB3HSVKC47&lid=LSTWATG3VYB3HSVKC47Q3TJ2I&marketplace=FLIPKART&q=watches&store=r18&srno=s_1_1&otracker=search&fm=organic&iid=en_JfI_wVTToVeQkWUimqv6J6AJqZKHQuzKvkdFhsN1EcoindCbrG5fmJIj7cOrBqkEO8PYqpZEpPreQSBrQ8phOg%3D%3D&ppt=None&ppn=None&ssid=fd949nxt4w0000001716871325720&qH=2d6b6aad43dffa91
# https://www.flipkart.com/matrix-softest-silicone-strap-antique-2-0-day-date-analog-watch-men-women/p/itmcae5e1ed938be?pid=WATGUTVZGUCMJYTB&lid=LSTWATGUTVZGUCMJYTBNQKOCN&marketplace=FLIPKART&q=watches&store=r18&srno=s_1_2&otracker=search&fm=organic&iid=en_JfI_wVTToVeQkWUimqv6J6AJqZKHQuzKvkdFhsN1EcrdDDvClaYJDQ_sJxhFXKNkPyyr9paYd_LFZIuhEQuyMQ%3D%3D&ppt=None&ppn=None&ssid=fd949nxt4w0000001716871325720&qH=2d6b6aad43dffa91
# ...
